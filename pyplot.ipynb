# %% [markdown]
# # The Numpy Random Package
# [Official Documentation](https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html)
#
# ***

# %%
# Efficient numerical arrays
import numpy as np
# Plotting
import matplotlib.pyplot as plt

# %%
# change default style sheet.
plt.style.use('ggplot')
# change the default figure size.
plt.rcParams['figure.figsize'] = [10,5]

# %% [markdown]
# Seeding is important in random number generation. [1]

# %% [markdown]
# <br>
#
# ## numpy.random.normal
#
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
#
# ***

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

# %%
# Look at first ten items.
s[:10]
# Out:
# array([-0.02823278,  0.11933982, -0.05234252, -0.02784937, -0.00860547,
#         0.17790116,  0.04758476, -0.04072059, -0.06345536, -0.05809607])

# %%
abs(mu - np.mean(s))
0.0  # may vary
# Out:
# 0.0

# %%
import matplotlib.pyplot as plt
count, bins, ignored = plt.hist(s, 30, density=True)
f =  1/(sigma * np.sqrt(2*np.pi)) * np.exp(-(bins - mu)**2/(2 * sigma**2))
plt.plot(bins, f,
         linewidth=2)
plt.show()

# %% [markdown]
# # References:
# [1]. https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
# [2]. https://numpy.org/doc/stable/reference/random/index.html
